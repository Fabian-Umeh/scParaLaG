# %%
# !git clone https://github.com/OmicsML/dance.git
# !pip install -r dance/requirements.txt
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install dgl -f https://data.dgl.ai/wheels/torch-2.2/cu121/repo.html
# !pip install pydance
# !pip install --force-reinstall torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install numpy==1.24.0
# !pip install anndata==0.10.8

# %% [markdown]
# ##**ADT2GEX -- No pathway**

# %% [markdown]
# #### **Babel**

# %%
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda --seed 1
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda --seed 2
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda --seed 3
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda --seed 4
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda --seed 5
# Out:
# [INFO][2025-04-08 17:45:49,066][dance][set_seed] Setting global random seed to 1
# [INFO][2025-04-08 17:45:49,066][dance][<module>] Parameter subtask: openproblems_bmmc_cite_phase2_mod2
# Parameter subtask: openproblems_bmmc_cite_phase2_mod2
# [INFO][2025-04-08 17:45:49,066][dance][<module>] Parameter device: cuda
# Parameter device: cuda
# [INFO][2025-04-08 17:45:49,066][dance][<module>] Parameter cpus: 1
# Parameter cpus: 1
# [INFO][2025-04-08 17:45:49,067][dance][<module>] Parameter seed: 1
# Parameter seed: 1
# [INFO][2025-04-08 17:45:49,067][dance][<module>] Parameter runs: 1
# Parameter runs: 1
# [INFO][2025-04-08 17:45:49,067][dance][<module>] Parameter model_folder: ./models
# Parameter model_folder: ./models
# [INFO][2025-04-08 17:45:49,067][dance][<module>] Parameter outdir: /content/logs
# Parameter outdir: /content/logs
# [INFO][2025-04-08 17:45:49,067][dance][<module>] Parameter cache_dir: /content/cache
# Parameter cache_dir: /content/cache
# ...

# %% [markdown]
# #### **CMAE**

# %%
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda --seed 1
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda --seed 2
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda --seed 3
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda --seed 4
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda --seed 5
# Out:
# [INFO][2025-04-08 18:17:46,754][dance][set_seed] Setting global random seed to 1
# 2025-04-08 18:17:46,754 - dance - INFO - Parameter output_path: ./predict_modality/output_cmae
# 2025-04-08 18:17:46,755 - dance - INFO - Parameter cache_dir: /content/cache
# 2025-04-08 18:17:46,755 - dance - INFO - Parameter log_dir: /content/logs
# 2025-04-08 18:17:46,755 - dance - INFO - Parameter resume: False
# 2025-04-08 18:17:46,755 - dance - INFO - Parameter subtask: openproblems_bmmc_cite_phase2_mod2
# 2025-04-08 18:17:46,755 - dance - INFO - Parameter device: cuda
# 2025-04-08 18:17:46,755 - dance - INFO - Parameter cpus: 1
# 2025-04-08 18:17:46,755 - dance - INFO - Parameter seed: 1
# 2025-04-08 18:17:46,755 - dance - INFO - Parameter runs: 1
# 2025-04-08 18:17:46,755 - dance - INFO - Parameter max_epochs: 100
# 2025-04-08 18:17:46,755 - dance - INFO - Parameter batch_size: 64
# 2025-04-08 18:17:46,755 - dance - INFO - Parameter log_data: True
# ...

# %% [markdown]
# #### **SCMM**

# %%
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda --seed 1
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda --seed 2
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda --seed 3
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda --seed 4
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda --seed 5
# Out:
# [INFO][2025-04-09 21:00:59,698][dance][set_seed] Setting global random seed to 1
# 2025-04-09 21:00:59,698 - dance - INFO - Parameter output_path: /content/predict_modality/output_scmm
# 2025-04-09 21:00:59,698 - dance - INFO - Parameter cache_dir: /content/cache
# 2025-04-09 21:00:59,698 - dance - INFO - Parameter log_dir: /content/logs
# 2025-04-09 21:00:59,698 - dance - INFO - Parameter resume: False
# 2025-04-09 21:00:59,698 - dance - INFO - Parameter subtask: openproblems_bmmc_cite_phase2_mod2
# 2025-04-09 21:00:59,698 - dance - INFO - Parameter device: cuda
# 2025-04-09 21:00:59,699 - dance - INFO - Parameter cpus: 1
# 2025-04-09 21:00:59,699 - dance - INFO - Parameter seed: 1
# 2025-04-09 21:00:59,699 - dance - INFO - Parameter runs: 1
# 2025-04-09 21:00:59,699 - dance - INFO - Parameter experiment: test
# 2025-04-09 21:00:59,699 - dance - INFO - Parameter obj: m_elbo_naive_warmup
# 2025-04-09 21:00:59,699 - dance - INFO - Parameter llik_scaling: 1.0
# ...

# %% [markdown]
# #### **SCMOGCN**

# %%
# !python /content/dance/examples/multi_modality/predict_modality/scmogcn.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda -es 300 --seed 1 --low_memory
# !python /content/dance/examples/multi_modality/predict_modality/scmogcn.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda -es 300 --seed 2 --low_memory
# !python /content/dance/examples/multi_modality/predict_modality/scmogcn.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda -es 300 --seed 3 --low_memory
# !python /content/dance/examples/multi_modality/predict_modality/scmogcn.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda -es 300 --seed 4 --low_memory
# !python /content/dance/examples/multi_modality/predict_modality/scmogcn.py --subtask openproblems_bmmc_cite_phase2_mod2 --device cuda -es 300 --seed 5 --low_memory
# Out:
# 2025-04-10 09:14:51,729 - dance - INFO - Script arguments: Namespace(prefix='dance_openproblems_bmmc_atac2rna_test', subtask='openproblems_bmmc_cite_phase2_mod2', pathway_weight='pearson', pathway_threshold=-1.0, log_folder='./logs', cache_dir='./cache', model_folder='./models', result_folder='./results', epoch=15000, no_batch_features=False, pathway=False, residual='res_cat', initial_residual=False, pathway_aggregation='alpha', pathway_alpha=0.25, no_readout_concatenate=False, batch_size=1000, normalization='group', activation='gelu', embedding_layers=1, readout_layers=1, conv_layers=4, agg_function='mean', device='cuda', save_best=False, save_final=False, learning_rate=0.01, lr_decay=0.99, weight_decay=1e-05, hidden_size=48, edge_dropout=0.3, model_dropout=0.2, early_stopping=300, cpu=1, output_relu='none', inductive=False, subpath_activation=False, cell_init='none', batch_seperation=False, pathway_path='./data/h.all.v7.4', seed=1, runs=1, weighted_sum=False, sampling=False, node_s
# ...

# %% [markdown]
# ## **GEX2ADT**

# %% [markdown]
# #### **Babel**

# %%
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 1
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 2
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 3
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 4
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 5
# Out:
# [INFO][2025-04-10 14:12:54,334][dance][set_seed] Setting global random seed to 1
# [INFO][2025-04-10 14:12:54,334][dance][<module>] Parameter subtask: openproblems_bmmc_cite_phase2_rna
# Parameter subtask: openproblems_bmmc_cite_phase2_rna
# [INFO][2025-04-10 14:12:54,334][dance][<module>] Parameter device: cuda
# Parameter device: cuda
# [INFO][2025-04-10 14:12:54,335][dance][<module>] Parameter cpus: 1
# Parameter cpus: 1
# [INFO][2025-04-10 14:12:54,335][dance][<module>] Parameter seed: 1
# Parameter seed: 1
# [INFO][2025-04-10 14:12:54,335][dance][<module>] Parameter runs: 1
# Parameter runs: 1
# [INFO][2025-04-10 14:12:54,335][dance][<module>] Parameter model_folder: ./models
# Parameter model_folder: ./models
# [INFO][2025-04-10 14:12:54,335][dance][<module>] Parameter outdir: /content/logs
# Parameter outdir: /content/logs
# [INFO][2025-04-10 14:12:54,335][dance][<module>] Parameter cache_dir: /content/cache
# Parameter cache_dir: /content/cache
# ...

# %% [markdown]
# #### **CMAE**

# %%
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 1
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 2
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 3
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 4
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 5
# Out:
# [INFO][2025-04-10 14:33:21,370][dance][set_seed] Setting global random seed to 1
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter output_path: ./predict_modality/output_cmae
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter cache_dir: /content/cache
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter log_dir: /content/logs
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter resume: False
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter subtask: openproblems_bmmc_cite_phase2_rna
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter device: cuda
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter cpus: 1
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter seed: 1
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter runs: 1
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter max_epochs: 100
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter batch_size: 64
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter log_data: True
# ...

# %% [markdown]
# #### **SCMM**

# %%
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 1
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 2
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 3
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 4
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 5
# Out:
# [INFO][2025-04-10 18:08:55,374][dance][set_seed] Setting global random seed to 1
# 2025-04-10 18:08:55,374 - dance - INFO - Parameter output_path: /content/predict_modality/output_scmm
# 2025-04-10 18:08:55,374 - dance - INFO - Parameter cache_dir: /content/cache
# 2025-04-10 18:08:55,374 - dance - INFO - Parameter log_dir: /content/logs
# 2025-04-10 18:08:55,375 - dance - INFO - Parameter resume: False
# 2025-04-10 18:08:55,375 - dance - INFO - Parameter subtask: openproblems_bmmc_cite_phase2_rna
# 2025-04-10 18:08:55,375 - dance - INFO - Parameter device: cuda
# 2025-04-10 18:08:55,375 - dance - INFO - Parameter cpus: 1
# 2025-04-10 18:08:55,375 - dance - INFO - Parameter seed: 1
# 2025-04-10 18:08:55,375 - dance - INFO - Parameter runs: 1
# 2025-04-10 18:08:55,375 - dance - INFO - Parameter experiment: test
# 2025-04-10 18:08:55,375 - dance - INFO - Parameter obj: m_elbo_naive_warmup
# 2025-04-10 18:08:55,375 - dance - INFO - Parameter llik_scaling: 1.0
# ...

# %% [markdown]
# #### **SCMOGCN**

# %%
# !python /content/dance/examples/multi_modality/predict_modality/scmogcn.py --subtask openproblems_bmmc_cite_phase2_rna  --device cuda   --seed 1
# Out:
# Streaming output truncated to the last 5000 lines.
# training:  0.32150184982473623
# valid:  0.31215268146148956
# testing:  0.41360877026707576
# epoch 1255
# training:  0.3214531569312377
# valid:  0.3121407112365503
# testing:  0.4106659038846768
# epoch 1256
# training:  0.3213353804852706
# valid:  0.3120846133382002
# testing:  0.41014211721140476
# epoch 1257
# training:  0.3214419386748424
# valid:  0.3118657948429345
# testing:  0.4159499998672032
# epoch 1258
# training:  0.32123692793912273
# valid:  0.3117654034113781
# testing:  0.4148536716862374
# epoch 1259
# training:  0.321549678024145
# valid:  0.3115088001985911
# testing:  0.4135950616946171
# epoch 1260
# training:  0.32092986275148494
# valid:  0.31202404015797425
# testing:  0.41215256378795306
# epoch 1261
# training:  0.32144996996639275
# valid:  0.3122756987496024
# testing:  0.41278983611990944
# epoch 1262
# training:  0.3214827420458568
# valid:  0.31211612488820534
# testing:  0.4133517805464203
# ...

# %%
# !python /content/dance/examples/multi_modality/predict_modality/scmogcn.py --subtask openproblems_bmmc_cite_phase2_rna  --device cuda   --seed 2
# Out:
# Streaming output truncated to the last 5000 lines.
# training:  0
# testing:  0.1782441322242306
# epoch 948
# training:  0.1571145043372804
# valid:  0.15638601820097903
# testing:  0.17834390147891044
# epoch 949
# training:  0.1571009886735569
# valid:  0.15637857987897688
# testing:  0.17824784192361195
# epoch 950
# training:  0.15706045249305683
# valid:  0.15638183158288252
# testing:  0.17824211536935203
# epoch 951
# training:  0.1570693349440218
# valid:  0.15641829248993155
# testing:  0.1783830835138779
# ...

# %%
# !python /content/dance/examples/multi_modality/predict_modality/scmogcn.py --subtask openproblems_bmmc_multiome_phase2_rna  --device cuda   --seed 5
# Out:
# Streaming output truncated to the last 5000 lines.
# training:  0.15784020062747364
# valid:  0.15702616318012394
# testing:  0.17895288192837766
# epoch 439
# training:  0.15783761032434765
# valid:  0.157024846492037
# testing:  0.17895866900454369
# epoch 440
# training:  0.15783464233935007
# valid:  0.15702268164302988
# testing:  0.17896029268294233
# epoch 441
# training:  0.15783713828275234
# valid:  0.15702062352602453
# testing:  0.1789528715197987
# epoch 442
# training:  0.15783467774307855
# valid:  0.15701917630367673
# testing:  0.17894349314412822
# epoch 443
# training:  0.15783484886098753
# valid:  0.15702159031057114
# testing:  0.17894159867338938
# epoch 444
# training:  0.1578348665628296
# valid:  0.15701829254248653
# testing:  0.17893809072681469
# epoch 445
# training:  0.15783381625009787
# valid:  0.15701704696457816
# testing:  0.1789447005985293
# epoch 446
# training:  0.1578341997920741
# valid:  0.1570163411327107
# testing:  0.1789503734433375
# ...

# %% [markdown]
# #### **Babel**

# %%
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_multiome_phase2_rna --device cuda --seed 1
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_multiome_phase2_rna --device cuda --seed 2
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_multiome_phase2_rna --device cuda --seed 3
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_multiome_phase2_rna --device cuda --seed 4
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_multiome_phase2_rna --device cuda --seed 5
# Out:
# [INFO][2025-04-12 17:40:30,864][dance][set_seed] Setting global random seed to 1
# [INFO][2025-04-12 17:40:30,864][dance][<module>] Parameter subtask: openproblems_bmmc_multiome_phase2_rna
# Parameter subtask: openproblems_bmmc_multiome_phase2_rna
# [INFO][2025-04-12 17:40:30,864][dance][<module>] Parameter device: cuda
# Parameter device: cuda
# [INFO][2025-04-12 17:40:30,864][dance][<module>] Parameter cpus: 1
# Parameter cpus: 1
# [INFO][2025-04-12 17:40:30,864][dance][<module>] Parameter seed: 1
# Parameter seed: 1
# [INFO][2025-04-12 17:40:30,864][dance][<module>] Parameter runs: 1
# Parameter runs: 1
# [INFO][2025-04-12 17:40:30,865][dance][<module>] Parameter model_folder: ./models
# Parameter model_folder: ./models
# [INFO][2025-04-12 17:40:30,865][dance][<module>] Parameter outdir: /content/logs
# Parameter outdir: /content/logs
# [INFO][2025-04-12 17:40:30,865][dance][<module>] Parameter cache_dir: /content/cache
# Parameter cache_dir: /content/cache
# ...

# %% [markdown]
# #### **CMAE**

# %%
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_multiome_phase2_rna --device cuda --seed 1
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_multiome_phase2_rna --device cuda --seed 2
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_multiome_phase2_rna --device cuda --seed 3
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_multiome_phase2_rna --device cuda --seed 4
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_multiome_phase2_rna --device cuda --seed 5
# Out:
# [INFO][2025-04-12 17:54:18,823][dance][set_seed] Setting global random seed to 1
# 2025-04-12 17:54:18,823 - dance - INFO - Parameter output_path: ./predict_modality/output_cmae
# 2025-04-12 17:54:18,823 - dance - INFO - Parameter cache_dir: /content/cache
# 2025-04-12 17:54:18,823 - dance - INFO - Parameter log_dir: /content/logs
# 2025-04-12 17:54:18,824 - dance - INFO - Parameter resume: False
# 2025-04-12 17:54:18,824 - dance - INFO - Parameter subtask: openproblems_bmmc_multiome_phase2_rna
# 2025-04-12 17:54:18,824 - dance - INFO - Parameter device: cuda
# 2025-04-12 17:54:18,824 - dance - INFO - Parameter cpus: 1
# 2025-04-12 17:54:18,824 - dance - INFO - Parameter seed: 1
# 2025-04-12 17:54:18,824 - dance - INFO - Parameter runs: 1
# 2025-04-12 17:54:18,824 - dance - INFO - Parameter max_epochs: 100
# 2025-04-12 17:54:18,824 - dance - INFO - Parameter batch_size: 64
# 2025-04-12 17:54:18,824 - dance - INFO - Parameter log_data: True
# ...

# %% [markdown]
# #### **SCMM**

# %%
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_multiome_phase2_rna --device cuda --seed 1
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_multiome_phase2_rna --device cuda --seed 2
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_multiome_phase2_rna --device cuda --seed 3
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_multiome_phase2_rna --device cuda --seed 4
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_multiome_phase2_rna --device cuda --seed 5
# Out:
# [INFO][2025-04-12 20:27:19,887][dance][set_seed] Setting global random seed to 1
# 2025-04-12 20:27:19,888 - dance - INFO - Parameter output_path: /content/predict_modality/output_scmm
# 2025-04-12 20:27:19,888 - dance - INFO - Parameter cache_dir: /content/cache
# 2025-04-12 20:27:19,888 - dance - INFO - Parameter log_dir: /content/logs
# 2025-04-12 20:27:19,888 - dance - INFO - Parameter resume: False
# 2025-04-12 20:27:19,888 - dance - INFO - Parameter subtask: openproblems_bmmc_multiome_phase2_rna
# 2025-04-12 20:27:19,888 - dance - INFO - Parameter device: cuda
# 2025-04-12 20:27:19,888 - dance - INFO - Parameter cpus: 1
# 2025-04-12 20:27:19,888 - dance - INFO - Parameter seed: 1
# 2025-04-12 20:27:19,888 - dance - INFO - Parameter runs: 1
# 2025-04-12 20:27:19,888 - dance - INFO - Parameter experiment: test
# 2025-04-12 20:27:19,888 - dance - INFO - Parameter obj: m_elbo_naive_warmup
# 2025-04-12 20:27:19,888 - dance - INFO - Parameter llik_scaling: 1.0
# ...

# %% [markdown]
# ## **GEX2ADT**

# %% [markdown]
# #### **Babel**

# %%
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 1
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 2
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 3
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 4
# !python /content/dance/examples/multi_modality/predict_modality/babel.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 5
# Out:
# [INFO][2025-04-10 14:12:54,334][dance][set_seed] Setting global random seed to 1
# [INFO][2025-04-10 14:12:54,334][dance][<module>] Parameter subtask: openproblems_bmmc_cite_phase2_rna
# Parameter subtask: openproblems_bmmc_cite_phase2_rna
# [INFO][2025-04-10 14:12:54,334][dance][<module>] Parameter device: cuda
# Parameter device: cuda
# [INFO][2025-04-10 14:12:54,335][dance][<module>] Parameter cpus: 1
# Parameter cpus: 1
# [INFO][2025-04-10 14:12:54,335][dance][<module>] Parameter seed: 1
# Parameter seed: 1
# [INFO][2025-04-10 14:12:54,335][dance][<module>] Parameter runs: 1
# Parameter runs: 1
# [INFO][2025-04-10 14:12:54,335][dance][<module>] Parameter model_folder: ./models
# Parameter model_folder: ./models
# [INFO][2025-04-10 14:12:54,335][dance][<module>] Parameter outdir: /content/logs
# Parameter outdir: /content/logs
# [INFO][2025-04-10 14:12:54,335][dance][<module>] Parameter cache_dir: /content/cache
# Parameter cache_dir: /content/cache
# ...

# %% [markdown]
# #### **CMAE**

# %%
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 1
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 2
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 3
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 4
# !python /content/dance/examples/multi_modality/predict_modality/cmae.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 5
# Out:
# [INFO][2025-04-10 14:33:21,370][dance][set_seed] Setting global random seed to 1
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter output_path: ./predict_modality/output_cmae
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter cache_dir: /content/cache
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter log_dir: /content/logs
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter resume: False
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter subtask: openproblems_bmmc_cite_phase2_rna
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter device: cuda
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter cpus: 1
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter seed: 1
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter runs: 1
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter max_epochs: 100
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter batch_size: 64
# 2025-04-10 14:33:21,371 - dance - INFO - Parameter log_data: True
# ...

# %% [markdown]
# #### **SCMM**

# %%
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 1
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 2
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 3
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 4
# !python /content/dance/examples/multi_modality/predict_modality/scmm.py --subtask openproblems_bmmc_cite_phase2_rna --device cuda --seed 5
# Out:
# [INFO][2025-04-10 18:08:55,374][dance][set_seed] Setting global random seed to 1
# 2025-04-10 18:08:55,374 - dance - INFO - Parameter output_path: /content/predict_modality/output_scmm
# 2025-04-10 18:08:55,374 - dance - INFO - Parameter cache_dir: /content/cache
# 2025-04-10 18:08:55,374 - dance - INFO - Parameter log_dir: /content/logs
# 2025-04-10 18:08:55,375 - dance - INFO - Parameter resume: False
# 2025-04-10 18:08:55,375 - dance - INFO - Parameter subtask: openproblems_bmmc_cite_phase2_rna
# 2025-04-10 18:08:55,375 - dance - INFO - Parameter device: cuda
# 2025-04-10 18:08:55,375 - dance - INFO - Parameter cpus: 1
# 2025-04-10 18:08:55,375 - dance - INFO - Parameter seed: 1
# 2025-04-10 18:08:55,375 - dance - INFO - Parameter runs: 1
# 2025-04-10 18:08:55,375 - dance - INFO - Parameter experiment: test
# 2025-04-10 18:08:55,375 - dance - INFO - Parameter obj: m_elbo_naive_warmup
# 2025-04-10 18:08:55,375 - dance - INFO - Parameter llik_scaling: 1.0
# ...

# %% [markdown]
# #### **SCMOGCN**

# %%
# !python /content/dance/examples/multi_modality/predict_modality/scmogcn.py --subtask GSE117089_mouse_gex2atac  --device cuda   --seed 1
# Out:
# 2025-04-19 23:39:03,909 - dance - INFO - Script arguments: Namespace(prefix='dance_openproblems_bmmc_atac2rna_test', subtask='GSE117089_mouse_gex2atac', pathway_weight='pearson', pathway_threshold=-1.0, log_folder='./logs', cache_dir='./cache', model_folder='./models', result_folder='./results', epoch=2500, no_batch_features=False, pathway=False, residual='res_cat', initial_residual=False, pathway_aggregation='alpha', pathway_alpha=0.25, no_readout_concatenate=False, batch_size=1000, normalization='group', activation='gelu', embedding_layers=1, readout_layers=1, conv_layers=4, agg_function='mean', device='cuda', save_best=False, save_final=False, learning_rate=0.01, lr_decay=0.99, weight_decay=1e-05, hidden_size=48, edge_dropout=0.3, model_dropout=0.2, early_stopping=200, cpu=1, output_relu='none', inductive=False, subpath_activation=False, cell_init='none', batch_seperation=False, pathway_path='', seed=1, runs=1, weighted_sum=False, sampling=False, node_sampling_rate=0.5, preprocess
# ...

# %%
# !python /content/dance/examples/multi_modality/predict_modality/scmogcn.py --subtask openproblems_bmmc_cite_phase2_rna  --device cuda   --seed 2
# Out:
# Streaming output truncated to the last 5000 lines.
# training:  0